# %% [markdown]
# ## Extract data from CSV

# %%
import pandas as pd
import numpy as np
from supabase import create_client
from dotenv import load_dotenv
import os

data = pd.read_csv("./data/consumer_complaints.csv")

data.head(10)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25628\1893787032.py:7: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("./data/consumer_complaints.csv")
#   date_received                  product  \
# 0    08/30/2013                 Mortgage
# 1    08/30/2013                 Mortgage
# 2    08/30/2013         Credit reporting
# 3    08/30/2013             Student loan
# 4    08/30/2013          Debt collection
# 5    08/30/2013              Credit card
# 6    08/30/2013              Credit card
# 7    08/30/2013  Bank account or service
# 8    08/30/2013  Bank account or service
# 9    09/17/2013                 Mortgage
#
#                               sub_product  \
# 0                          Other mortgage
# 1                          Other mortgage
# 2                                     NaN
# 3                Non-federal student loan
# 4                             Credit card
# 5                                     NaN
# 6                                     NaN
# 7                        Checking account
# 8                        Checking account
# 9  Conventional adjustable mortgage (ARM)
#
#                                       issue  \
# 0  Loan modification,collection,foreclosure
# 1  Loan servicing, payments, escrow account
# 2    Incorrect information on credit report
# 3                        Repaying your loan
# 4        False statements or representation
# 5              Application processing delay
# 6             Credit line increase/decrease
# 7                  Deposits and withdrawals
# 8                  Deposits and withdrawals
# 9  Loan modification,collection,foreclosure
#
#                            sub_issue consumer_complaint_narrative  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                     Account status                          NaN
# 3                 Repaying your loan                          NaN
# 4  Attempted to collect wrong amount                          NaN
# 5                                NaN                          NaN
# 6                                NaN                          NaN
# 7                                NaN                          NaN
# 8                                NaN                          NaN
# 9                                NaN                          NaN
#
#   company_public_response                          company state zipcode tags  \
# 0                     NaN                     U.S. Bancorp    CA   95993  NaN
# 1                     NaN            Wells Fargo & Company    CA   91104  NaN
# 2                     NaN            Wells Fargo & Company    NY   11764  NaN
# 3                     NaN          Navient Solutions, Inc.    MD   21402  NaN
# 4                     NaN  Resurgent Capital Services L.P.    GA   30106  NaN
# 5                     NaN                      Capital One    NY   12206  NaN
# 6                     NaN            Wells Fargo & Company    AZ   85730  NaN
# 7                     NaN                  Bank of America    IL   60660  NaN
# 8                     NaN                  Bank of America    GA   30016  NaN
# 9                     NaN             SunTrust Banks, Inc.    CA   94551  NaN
#
#   consumer_consent_provided submitted_via date_sent_to_company  \
# 0                       NaN      Referral           09/03/2013
# 1                       NaN      Referral           09/03/2013
# 2                       NaN   Postal mail           09/18/2013
# 3                       NaN         Email           08/30/2013
# 4                       NaN           Web           08/30/2013
# 5                       NaN         Phone           09/03/2013
# 6                       NaN   Postal mail           09/05/2013
# 7                       NaN      Referral           09/04/2013
# 8                       NaN      Referral           09/04/2013
# 9                       NaN           Web           09/18/2013
#
#   company_response_to_consumer timely_response consumer_disputed?  \
# 0      Closed with explanation             Yes                Yes
# 1      Closed with explanation             Yes                Yes
# 2      Closed with explanation             Yes                 No
# 3      Closed with explanation             Yes                Yes
# 4      Closed with explanation             Yes                Yes
# 5      Closed with explanation             Yes                Yes
# 6      Closed with explanation             Yes                 No
# 7      Closed with explanation             Yes                 No
# 8      Closed with explanation             Yes                 No
# 9      Closed with explanation             Yes                Yes
#
#    complaint_id
# 0        511074
# 1        511080
# 2        510473
# 3        510326
# 4        511067
# 5        510098
# 6        511062
# 7        511116
# 8        511091
# 9        530602

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Data Cleaning

# %%
print(data.isnull().sum())

# 2. Isi missing value per tipe kolom (menyesuaikan dataset)
# Isi sub_product dengan "Not Specified" jika null
data['sub_product'] = data['sub_product'].fillna('Not Specified')

# Isi sub_issue dengan "General" jika null
data['sub_issue'] = data['sub_issue'].fillna('General')

# Isi consumer_complaint_narrative dengan "No Narrative" jika null
data['consumer_complaint_narrative'] = data['consumer_complaint_narrative'].fillna('No Narrative')

# Zipcode: Ambil 5 digit pertama, jika invalid atau null isi dengan "00000"
data['zipcode'] = data['zipcode'].apply(lambda x: str(x)[:5] if pd.notnull(x) else '00000')

# Isi company_public_response dengan "No Response" jika null
data['company_public_response'] = data['company_public_response'].fillna('No Response')

# Isi tags dengan "No Tag" jika null
data['tags'] = data['tags'].fillna('No Tag')

# Isi consumer_consent_provided dengan "Not Provided" jika null
data['consumer_consent_provided'] = data['consumer_consent_provided'].fillna('Not Provided')

# Isi complaint_id dengan -1 jika null (ID tidak boleh kosong)
if data['complaint_id'].isnull().any():
    data['complaint_id'] = data['complaint_id'].fillna(-1)

# 3. Cek lagi missing values setelah diisi
print("\nSetelah diisi:\n", data.isnull().sum())
# Out:
# date_received                        0
# product                              0
# sub_product                     158322
# issue                                0
# sub_issue                       343335
# consumer_complaint_narrative    489151
# company_public_response         470833
# company                              0
# state                             4887
# zipcode                           4505
# tags                            477998
# consumer_consent_provided       432499
# submitted_via                        0
# date_sent_to_company                 0
# company_response_to_consumer         0
# timely_response                      0
# consumer_disputed?                   0
# complaint_id                         0
# dtype: int64
#
# Setelah diisi:
#  date_received                      0
# product                            0
# sub_product                        0
# issue                              0
# sub_issue                          0
# consumer_complaint_narrative       0
# company_public_response            0
# company                            0
# state                           4887
# zipcode                            0
# tags                               0
# consumer_consent_provided          0
# submitted_via                      0
# date_sent_to_company               0
# company_response_to_consumer       0
# timely_response                    0
# consumer_disputed?                 0
# complaint_id                       0
# dtype: int64

# %% [markdown]
# ### Data transformation

# %%
def generate_bigint():
    """Generates a valid BIGINT value"""
    return np.random.randint(1000000, 9999999)

# %%
def transform_data(df):
    """Transform data into star schema dimensions and fact table"""
    
    # Generate BIGINT for each dimension key
    df['complaint_detail_key'] = df['complaint_id'].apply(lambda x: generate_bigint()) if 'complaint_id' in df.columns else [generate_bigint() for _ in range(len(df))]
    df['product_key'] = [generate_bigint() for _ in range(len(df))] if 'product' not in df.columns else df['product'].apply(lambda x: generate_bigint())
    df['company_key'] = [generate_bigint() for _ in range(len(df))] if 'company' not in df.columns else df['company'].apply(lambda x: generate_bigint())
    df['location_key'] = [generate_bigint() for _ in range(len(df))]
    df['issue_key'] = [generate_bigint() for _ in range(len(df))]
    df['response_key'] = [generate_bigint() for _ in range(len(df))]
    
    # Generate complaint_count for fact table
    df['complaint_count'] = 1
    
    # Handle missing or misnamed columns by using get() to avoid KeyError
    df['consumer_complaint_narrative'] = df.get('consumer_complaint_narrative', None)
    df['company_public_response'] = df.get('company_public_response', None)
    df['tags'] = df.get('tags', None)
    df['consumer_disputed'] = df.get('consumer_disputed', None)

    # Transform dim_complaint_detail
    dim_complaint_detail = df[['complaint_id', 'consumer_complaint_narrative', 'company_public_response', 'tags']].drop_duplicates()
    # Rename 'complaint_id' to 'complaint_detail_key' to match the schema
    dim_complaint_detail.rename(columns={'complaint_id': 'complaint_detail_key'}, inplace=True)
    
    # Transform dim_product
    dim_product = df[['product_key', 'product', 'sub_product']].drop_duplicates()
    
    # Transform dim_company
    dim_company = df[['company_key', 'company']].drop_duplicates()
    
    # Transform dim_location
    dim_location = df[['location_key', 'state', 'zipcode']].drop_duplicates()
    
    # Transform dim_issue
    dim_issue = df[['issue_key', 'issue', 'sub_issue']].drop_duplicates()

    # Transform dim_response
    dim_response = df[['response_key', 'submitted_via', 'company_response_to_consumer', 
                       'consumer_consent_provided', 'timely_response', 'consumer_disputed']].drop_duplicates()

    # Transform dim_date
    dim_date = pd.DataFrame()
    dim_date['date_key'] = pd.to_datetime(df['date_received']).dt.date  # Use 'date_received' here
    dim_date['full_date'] = pd.to_datetime(df['date_received'])  # Use 'date_received' here
    dim_date['year'] = dim_date['full_date'].dt.year
    dim_date['quarter'] = dim_date['full_date'].dt.quarter
    dim_date['month'] = dim_date['full_date'].dt.month
    dim_date['day'] = dim_date['full_date'].dt.day
    dim_date['day_of_week'] = dim_date['full_date'].dt.dayofweek
    dim_date['month_name'] = dim_date['full_date'].dt.month_name()
    dim_date['day_name'] = dim_date['full_date'].dt.day_name()
    dim_date['created_at'] = pd.to_datetime(df['created_at']) if 'created_at' in df.columns else None
    dim_date = dim_date.drop_duplicates()

    # Transform fact_complaints
    fact_complaints = df[['complaint_detail_key', 'date_received', 'date_sent_to_company', 
                           'product_key', 'company_key', 'location_key', 
                           'issue_key', 'response_key', 
                           'complaint_count']].drop_duplicates()
    
    # Since we are using BIGINT, there is no need to convert them to UUID
    # No UUID conversion needed, we can just merge using BIGINT
    fact_complaints = fact_complaints.merge(dim_complaint_detail[['complaint_detail_key']], 
                                            left_on='complaint_detail_key', right_on='complaint_detail_key', how='left')

    # Drop any unnecessary columns and ensure we have the correct 'complaint_detail_key'
    fact_complaints = fact_complaints.drop(columns=['complaint_detail_key'])
    fact_complaints = fact_complaints.rename(columns={'complaint_detail_key': 'complaint_detail_key'})

    # Ensure we are referencing the correct columns for date
    fact_complaints['date_received_key'] = pd.to_datetime(fact_complaints['date_received']).dt.date
    fact_complaints['date_sent_key'] = pd.to_datetime(fact_complaints['date_sent_to_company']).dt.date

    return dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints

# %% [markdown]
# ## Load Data To Supabase Postgres

# %%
import os
from dotenv import load_dotenv
from supabase import create_client

def load_to_supabase(dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints):
    """Fungsi untuk memuat data ke Supabase"""
    print("Loading data to Supabase...")

    # Load environment variables
    load_dotenv()
    url = os.getenv("SUPABASE_URL")
    key = os.getenv("SUPABASE_KEY")

    # Initialize Supabase client
    supabase = create_client(url, key)

    def load_table(df, table_name):
        """Fungsi untuk memasukkan data ke Supabase dalam batch"""
        if df.empty:
            print(f"Warning: {table_name} is empty. Skipping.")
            return 0
        
        print(f"Loading {len(df)} records to {table_name}...")

        # Convert DataFrame to list of dictionaries (records)
        records = df.to_dict(orient='records')

        # Insert records in batches to avoid payload limits
        batch_size = 1000  # Adjust based on your data size
        total_loaded = 0

        for i in range(0, len(records), batch_size):
            batch = records[i:i+batch_size]
            try:
                # Perform upsert (insert or update) operation
                response = supabase.table(table_name).upsert(batch).execute()
                total_loaded += len(batch)
                print(f"  Loaded batch {i//batch_size + 1}, Progress: {total_loaded}/{len(records)}")
            except Exception as e:
                print(f"  Error loading batch to {table_name}: {e}")
                continue

        print(f"Completed loading {total_loaded}/{len(records)} records to {table_name}")
        return total_loaded

    # Load data into each table
    results = {
        "dim_complaint_detail": load_table(dim_complaint_detail, "dim_complaint_detail"),
        "dim_product": load_table(dim_product, "dim_product"),
        "dim_company": load_table(dim_company, "dim_company"),
        "dim_location": load_table(dim_location, "dim_location"),
        "dim_issue": load_table(dim_issue, "dim_issue"),
        "dim_response": load_table(dim_response, "dim_response"),
        "dim_date": load_table(dim_date, "dim_date"),
        "fact_complaints": load_table(fact_complaints, "fact_complaints")
    }

    # Print summary of data loading results
    print("\nData loading summary:")
    for table, count in results.items():
        print(f"- {table}: {count} records")

    return results

# %%
dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints = transform_data(data)
load_to_supabase(dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints)
print("Data transformation and loading completed successfully.")
# Out:
# Loading data to Supabase...
# Loading 555957 records to dim_complaint_detail...
#   Loaded batch 1, Progress: 1000/555957
#   Loaded batch 2, Progress: 2000/555957
#   Loaded batch 3, Progress: 3000/555957
#   Loaded batch 4, Progress: 4000/555957
#   Loaded batch 5, Progress: 5000/555957
#   Loaded batch 6, Progress: 6000/555957
#   Loaded batch 7, Progress: 7000/555957
#   Loaded batch 8, Progress: 8000/555957
#   Loaded batch 9, Progress: 9000/555957
#   Loaded batch 10, Progress: 10000/555957
#   Loaded batch 11, Progress: 11000/555957
#   Loaded batch 12, Progress: 12000/555957
#   Loaded batch 13, Progress: 13000/555957
#   Loaded batch 14, Progress: 14000/555957
#   Loaded batch 15, Progress: 15000/555957
#   Loaded batch 16, Progress: 16000/555957
#   Loaded batch 17, Progress: 17000/555957
#   Loaded batch 18, Progress: 18000/555957
#   Loaded batch 19, Progress: 19000/555957
#   Loaded batch 20, Progress: 20000/555957
#   Loaded batch 21, Progress: 21000/555957
#   Loaded batch 22, Progress: 22000/555957
#   Loaded batch 23, Progress: 23000/555957
#   Loaded batch 24, Progress: 24000/555957
#   Loaded batch 25, Progress: 25000/555957
#   Loaded batch 26, Progress: 26000/555957
#   Loaded batch 27, Progress: 27000/555957
#   Loaded batch 28, Progress: 28000/555957
#   Loaded batch 29, Progress: 29000/555957
#   Loaded batch 30, Progress: 30000/555957
#   Loaded batch 31, Progress: 31000/555957
#   Loaded batch 32, Progress: 32000/555957
#   Loaded batch 33, Progress: 33000/555957
#   Loaded batch 34, Progress: 34000/555957
#   Loaded batch 35, Progress: 35000/555957
#   Loaded batch 36, Progress: 36000/555957
#   Loaded batch 37, Progress: 37000/555957
#   Loaded batch 38, Progress: 38000/555957
#   Loaded batch 39, Progress: 39000/555957
#   Loaded batch 40, Progress: 40000/555957
#   Loaded batch 41, Progress: 41000/555957
#   Loaded batch 42, Progress: 42000/555957
#   Loaded batch 43, Progress: 43000/555957
#   Loaded batch 44, Progress: 44000/555957
#   Loaded batch 45, Progress: 45000/555957
#   Loaded batch 46, Progress: 46000/555957
#   Loaded batch 47, Progress: 47000/555957
#   Loaded batch 48, Progress: 48000/555957
#   Loaded batch 49, Progress: 49000/555957
#   Loaded batch 50, Progress: 50000/555957
#   Loaded batch 51, Progress: 51000/555957
#   Loaded batch 52, Progress: 52000/555957
#   Loaded batch 53, Progress: 53000/555957
#   Loaded batch 54, Progress: 54000/555957
#   Loaded batch 55, Progress: 55000/555957
#   Loaded batch 56, Progress: 56000/555957
#   Loaded batch 57, Progress: 57000/555957
#   Loaded batch 58, Progress: 58000/555957
#   Loaded batch 59, Progress: 59000/555957
#   Loaded batch 60, Progress: 60000/555957
#   Loaded batch 61, Progress: 61000/555957
#   Loaded batch 62, Progress: 62000/555957
#   Loaded batch 63, Progress: 63000/555957
#   Loaded batch 64, Progress: 64000/555957
#   Loaded batch 65, Progress: 65000/555957
#   Loaded batch 66, Progress: 66000/555957
#   Loaded batch 67, Progress: 67000/555957
#   Loaded batch 68, Progress: 68000/555957
#   Loaded batch 69, Progress: 69000/555957
#   Loaded batch 70, Progress: 70000/555957
#   Loaded batch 71, Progress: 71000/555957
#   Loaded batch 72, Progress: 72000/555957
#   Loaded batch 73, Progress: 73000/555957
#   Loaded batch 74, Progress: 74000/555957
#   Loaded batch 75, Progress: 75000/555957
#   Loaded batch 76, Progress: 76000/555957
#   Loaded batch 77, Progress: 77000/555957
#   Loaded batch 78, Progress: 78000/555957
#   Loaded batch 79, Progress: 79000/555957
#   Loaded batch 80, Progress: 80000/555957
#   Loaded batch 81, Progress: 81000/555957
#   Loaded batch 82, Progress: 82000/555957
#   Loaded batch 83, Progress: 83000/555957
#   Loaded batch 84, Progress: 84000/555957
#   Loaded batch 85, Progress: 85000/555957
#   Loaded batch 86, Progress: 86000/555957
#   Loaded batch 87, Progress: 87000/555957
#   Loaded batch 88, Progress: 88000/555957
#   Loaded batch 89, Progress: 89000/555957
#   Loaded batch 90, Progress: 90000/555957
#   Loaded batch 91, Progress: 91000/555957
#   Loaded batch 92, Progress: 92000/555957
#   Loaded batch 93, Progress: 93000/555957
#   Loaded batch 94, Progress: 94000/555957
#   Loaded batch 95, Progress: 95000/555957
#   Loaded batch 96, Progress: 96000/555957
#   Loaded batch 97, Progress: 97000/555957
#   Loaded batch 98, Progress: 98000/555957
#   Loaded batch 99, Progress: 99000/555957
#   Loaded batch 100, Progress: 100000/555957
#   Loaded batch 101, Progress: 101000/555957
#   Loaded batch 102, Progress: 102000/555957
#   Loaded batch 103, Progress: 103000/555957
#   Loaded batch 104, Progress: 104000/555957
#   Loaded batch 105, Progress: 105000/555957
#   Loaded batch 106, Progress: 106000/555957
#   Loaded batch 107, Progress: 107000/555957
#   Loaded batch 108, Progress: 108000/555957
#   Loaded batch 109, Progress: 109000/555957
#   Loaded batch 110, Progress: 110000/555957
#   Loaded batch 111, Progress: 111000/555957
#   Loaded batch 112, Progress: 112000/555957
#   Loaded batch 113, Progress: 113000/555957
#   Loaded batch 114, Progress: 114000/555957
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[211], line 2
#       1 dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints = transform_data(data)
# ----> 2 load_to_supabase(dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints)
#       3 print("Data transformation and loading completed successfully.")
#
# Cell In[210], line 48, in load_to_supabase(dim_complaint_detail, dim_product, dim_company, dim_location, dim_issue, dim_response, dim_date, fact_complaints)
#      44     return total_loaded
#      46 # Load data into each table
#      47 results = {
# ---> 48     "dim_complaint_detail": load_table(dim_complaint_detail, "dim_complaint_detail"),
#      49     "dim_product": load_table(dim_product, "dim_product"),
#      50     "dim_company": load_table(dim_company, "dim_company"),
#      51     "dim_location": load_table(dim_location, "dim_location"),
#      52     "dim_issue": load_table(dim_issue, "dim_issue"),
#      53     "dim_response": load_table(dim_response, "dim_response"),
#      54     "dim_date": load_table(dim_date, "dim_date"),
#      55     "fact_complaints": load_table(fact_complaints, "fact_complaints")
#      56 }
#      58 # Print summary of data loading results
#      59 print("\nData loading summary:")
#
# Cell In[210], line 36, in load_to_supabase.<locals>.load_table(df, table_name)
#      33 batch = records[i:i+batch_size]
#      34 try:
#      35     # Perform upsert (insert or update) operation
# ---> 36     response = supabase.table(table_name).upsert(batch).execute()
#      37     total_loaded += len(batch)
#      38     print(f"  Loaded batch {i//batch_size + 1}, Progress: {total_loaded}/{len(records)}")
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\postgrest\_sync\request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)     55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if r.is_success:
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\http2.py:187, in HTTP2Connection.handle_request(self, request)
#     183     # If h2 raises a protocol error in some other state then we
#     184     # must somehow have made a protocol violation.
#     185     raise LocalProtocolError(exc)  # pragma: nocover
# --> 187 raise exc
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\http2.py:150, in HTTP2Connection.handle_request(self, request)
#     146     self._send_request_body(request=request, stream_id=stream_id)
#     147 with Trace(
#     148     "receive_response_headers", logger, request, kwargs
#     149 ) as trace:
# --> 150     status, headers = self._receive_response(
#     151         request=request, stream_id=stream_id
#     152     )
#     153     trace.return_value = (status, headers)
#     155 return Response(
#     156     status=status,
#     157     headers=headers,
#    (...)    163     },
#     164 )
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\http2.py:294, in HTTP2Connection._receive_response(self, request, stream_id)
#     290 """
#     291 Return the response status code and headers for a given stream ID.
#     292 """
#     293 while True:
# --> 294     event = self._receive_stream_event(request, stream_id)
#     295     if isinstance(event, h2.events.ResponseReceived):
#     296         break
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\http2.py:336, in HTTP2Connection._receive_stream_event(self, request, stream_id)
#     330 """
#     331 Return the next available event for a given stream ID.
#     332
#     333 Will read more data from the network if required.
#     334 """
#     335 while not self._events.get(stream_id):
# --> 336     self._receive_events(request, stream_id)
#     337 event = self._events[stream_id].pop(0)
#     338 if isinstance(event, h2.events.StreamReset):
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\http2.py:364, in HTTP2Connection._receive_events(self, request, stream_id)
#     357 # This conditional is a bit icky. We don't want to block reading if we've
#     358 # actually got an event to return for a given stream. We need to do that
#     359 # check *within* the atomic read lock. Though it also need to be optional,
#     360 # because when we call it from `_wait_for_outgoing_flow` we *do* want to
#     361 # block until we've available flow control, event when we have events
#     362 # pending for the stream ID we're attempting to send on.
#     363 if stream_id is None or not self._events.get(stream_id):
# --> 364     events = self._read_incoming_data(request)
#     365     for event in events:
#     366         if isinstance(event, h2.events.RemoteSettingsChanged):
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_sync\http2.py:441, in HTTP2Connection._read_incoming_data(self, request)
#     438     raise self._read_exception  # pragma: nocover
#     440 try:
# --> 441     data = self._network_stream.read(self.READ_NUM_BYTES, timeout)
#     442     if data == b"":
#     443         raise RemoteProtocolError("Server disconnected")
#
# File c:\Users\USER\Documents\code\tugas-kuliah\tubes-bi\py\venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
