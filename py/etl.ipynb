# %% [markdown]
# ## Extract data from CSV

# %%
import pandas as pd
import numpy as np
from supabase import create_client
from dotenv import load_dotenv
import os
import hashlib

load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))

# %%
def make_key(text):
    return int(hashlib.md5(str(text).encode()).hexdigest()[:8], 16)

# %%
print("📂 EXTRACT: Loading raw data...")

# Load data
data = pd.read_csv("./data/consumer_complaints.csv", low_memory=False)
print(f"📊 Loaded: {len(data):,} rows")

# Show data info
print(f"📅 Date range: {data['date_received'].min()} to {data['date_received'].max()}")
print(f"🏢 Companies: {data['company'].nunique():,}")
print(f"📋 Products: {data['product'].nunique()}")
# Out:
# 📂 EXTRACT: Loading raw data...
# 📊 Loaded: 555,957 rows
# 📅 Date range: 01/01/2012 to 12/31/2015
# 🏢 Companies: 3,605
# 📋 Products: 11

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Data Cleaning

# %%
def clean_data(df):
    """Clean data basics"""
    print("🧹 Cleaning data...")
    
    # Fill missing values
    df['sub_product'] = df['sub_product'].fillna('Not Specified')
    df['sub_issue'] = df['sub_issue'].fillna('General')
    df['consumer_complaint_narrative'] = df['consumer_complaint_narrative'].fillna('No Narrative')
    df['company_public_response'] = df['company_public_response'].fillna('No Response')
    df['tags'] = df['tags'].fillna('No Tag')
    df['consumer_consent_provided'] = df['consumer_consent_provided'].fillna('Not Provided')
    
    # Fix state (max 2 chars)
    df['state'] = df['state'].astype(str).str[:2].fillna('XX')
    df['zipcode'] = df['zipcode'].astype(str).str[:5].fillna('00000')
    
    # Fix column name
    if 'consumer_disputed?' in df.columns:
        df['consumer_disputed'] = df['consumer_disputed?']
        df = df.drop('consumer_disputed?', axis=1)
    
    print(f"✅ Data cleaned: {len(df)} rows")
    return df

# %% [markdown]
# ### Data transformation

# %%
def process_row(row):
    """Process 1 row dan buat records untuk semua tabel"""
    
    # Generate keys
    date_rec = pd.to_datetime(row['date_received']).date()
    date_sent = pd.to_datetime(row['date_sent_to_company']).date()
    product_key = make_key(f"{row['product']}_{row['sub_product']}")
    company_key = make_key(row['company'])
    location_key = make_key(f"{row['state']}_{row['zipcode']}")
    issue_key = make_key(f"{row['issue']}_{row['sub_issue']}")
    response_key = make_key(f"{row['submitted_via']}_{row['company_response_to_consumer']}")
    
    # Date records (both dates)
    dates = []
    for date_val, date_col in [(date_rec, row['date_received']), (date_sent, row['date_sent_to_company'])]:
        dt = pd.to_datetime(date_col)
        dates.append({
            'date_key': str(date_val),
            'full_date': str(date_val),
            'year': dt.year,
            'quarter': dt.quarter,
            'month': dt.month,
            'day': dt.day,
            'day_of_week': dt.dayofweek,
            'month_name': dt.month_name(),
            'day_name': dt.day_name()
        })
    
    # Return ALL table records for this row
    return {
        'dim_date': dates,
        'dim_product': [{
            'product_key': product_key,
            'product': row['product'],
            'sub_product': row['sub_product']
        }],
        'dim_company': [{
            'company_key': company_key,
            'company': row['company']
        }],
        'dim_location': [{
            'location_key': location_key,
            'state': row['state'],
            'zipcode': row['zipcode']
        }],
        'dim_issue': [{
            'issue_key': issue_key,
            'issue': row['issue'],
            'sub_issue': row['sub_issue']
        }],
        'dim_response': [{
            'response_key': response_key,
            'submitted_via': row['submitted_via'],
            'company_response_to_consumer': row['company_response_to_consumer'],
            'consumer_consent_provided': row['consumer_consent_provided'],
            'timely_response': row['timely_response'],
            'consumer_disputed': row['consumer_disputed']
        }],
        'dim_complaint_detail': [{
            'complaint_detail_key': int(row['complaint_id']),
            'consumer_complaint_narrative': row['consumer_complaint_narrative'],
            'company_public_response': row['company_public_response'],
            'tags': row['tags']
        }],
        'fact_complaints': [{
            'complaint_detail_key': int(row['complaint_id']),
            'date_received_key': str(date_rec),
            'date_sent_key': str(date_sent),
            'product_key': product_key,
            'company_key': company_key,
            'location_key': location_key,
            'issue_key': issue_key,
            'response_key': response_key,
            'complaint_count': 1
        }]
    }

print("🔧 Helper functions ready")
# Out:
# 🔧 Helper functions ready

# %%
print("\n🔧 TRANSFORM: Cleaning data...")

# Clean the data
cleaned_data = clean_data(data)

# Show missing values after cleaning
missing = cleaned_data.isnull().sum()
print(f"❓ Missing values: {missing.sum()} total")
if missing.sum() > 0:
    print(missing[missing > 0])

# Sample processed row
print("\n📋 Sample of 1 row transformation:")
sample_row = cleaned_data.iloc[0]
sample_records = process_row(sample_row)

print(f"Input: 1 row (complaint_id: {sample_row['complaint_id']})")
print("Output records to tables:")
for table, records in sample_records.items():
    print(f"  📊 {table}: {len(records)} record(s)")

print("✅ Transform ready")
# Out:
# 🔧 TRANSFORM: Cleaning data...
# 🧹 Cleaning data...
# ✅ Data cleaned: 555957 rows
# ❓ Missing values: 0 total
#
# 📋 Sample of 1 row transformation:
# Input: 1 row (complaint_id: 511074)
# Output records to tables:
#   📊 dim_date: 2 record(s)
#   📊 dim_product: 1 record(s)
#   📊 dim_company: 1 record(s)
#   📊 dim_location: 1 record(s)
#   📊 dim_issue: 1 record(s)
#   📊 dim_response: 1 record(s)
#   📊 dim_complaint_detail: 1 record(s)
#   📊 fact_complaints: 1 record(s)
# ✅ Transform ready

# %% [markdown]
# ## Load Data To Supabase Postgres

# %%
print("\n📤 LOAD: Processing batches to data warehouse...")

batch_size = 100
total_rows = len(cleaned_data)
batch_count = 0

# Process in batches
for i in range(0, total_rows, batch_size):
    batch_count += 1
    batch = cleaned_data.iloc[i:i+batch_size]
    
    print(f"\n📦 Batch {batch_count}: Processing rows {i+1} to {min(i+batch_size, total_rows)}")
    
    # Initialize batch containers
    all_batch_records = {
        'dim_date': [], 'dim_product': [], 'dim_company': [], 'dim_location': [],
        'dim_issue': [], 'dim_response': [], 'dim_complaint_detail': [], 'fact_complaints': []
    }
    
    # Process each row in batch
    for _, row in batch.iterrows():
        try:
            row_records = process_row(row)
            
            # Add records from this row to batch
            for table, records in row_records.items():
                all_batch_records[table].extend(records)
                
        except Exception as e:
            print(f"⚠️ Error processing row {row.name}: {e}")
            continue
    
    # Remove duplicates in dimensions
    for table in all_batch_records:
        if table == 'dim_date':
            # Remove duplicate dates
            seen = set()
            unique = []
            for record in all_batch_records[table]:
                if record['date_key'] not in seen:
                    seen.add(record['date_key'])
                    unique.append(record)
            all_batch_records[table] = unique
            
        elif table.startswith('dim_') and table != 'dim_date':
            # Remove duplicate dimensions
            key_field = f"{table.replace('dim_', '')}_key"
            seen = set()
            unique = []
            for record in all_batch_records[table]:
                key = record.get(key_field)
                if key not in seen:
                    seen.add(key)
                    unique.append(record)
            all_batch_records[table] = unique
    
    # Load to database in proper order
    load_order = ['dim_date', 'dim_product', 'dim_company', 'dim_location', 
                  'dim_issue', 'dim_response', 'dim_complaint_detail', 'fact_complaints']
    
    batch_total = 0
    for table in load_order:
        records = all_batch_records.get(table, [])
        if records:
            try:
                response = supabase.table(table).upsert(records).execute()
                print(f"  ✅ {table}: {len(records)} records")
                batch_total += len(records)
            except Exception as e:
                print(f"  ❌ {table}: {e}")
    
    print(f"  📊 Batch total: {batch_total} records loaded")
    progress = min(i + batch_size, total_rows) / total_rows * 100
    print(f"  📈 Progress: {progress:.1f}%")

print(f"\n🎉 LOAD completed! Processed {batch_count} batches")
# Out:
# 📤 LOAD: Processing batches to data warehouse...
#
# 📦 Batch 1: Processing rows 1 to 100
#   ✅ dim_date: 17 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 429 records loaded
#   📈 Progress: 0.0%
#
# 📦 Batch 2: Processing rows 101 to 200
#   ✅ dim_date: 16 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 424 records loaded
#   📈 Progress: 0.0%
#
# 📦 Batch 3: Processing rows 201 to 300
#   ✅ dim_date: 18 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 37 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 423 records loaded
#   📈 Progress: 0.1%
#
# 📦 Batch 4: Processing rows 301 to 400
#   ✅ dim_date: 23 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 433 records loaded
#   📈 Progress: 0.1%
#
# 📦 Batch 5: Processing rows 401 to 500
#   ✅ dim_date: 18 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 17 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 431 records loaded
#   📈 Progress: 0.1%
#
# 📦 Batch 6: Processing rows 501 to 600
#   ✅ dim_date: 17 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 423 records loaded
#   📈 Progress: 0.1%
#
# 📦 Batch 7: Processing rows 601 to 700
#   ✅ dim_date: 17 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 78 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 7 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 410 records loaded
#   📈 Progress: 0.1%
#
# 📦 Batch 8: Processing rows 701 to 800
#   ✅ dim_date: 20 records
#   ✅ dim_product: 15 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 7 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 417 records loaded
#   📈 Progress: 0.1%
#
# 📦 Batch 9: Processing rows 801 to 900
#   ✅ dim_date: 17 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 30 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 419 records loaded
#   📈 Progress: 0.2%
#
# 📦 Batch 10: Processing rows 901 to 1000
#   ✅ dim_date: 19 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 0.2%
#
# 📦 Batch 11: Processing rows 1001 to 1100
#   ✅ dim_date: 19 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 40 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 413 records loaded
#   📈 Progress: 0.2%
#
# 📦 Batch 12: Processing rows 1101 to 1200
#   ✅ dim_date: 18 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 427 records loaded
#   📈 Progress: 0.2%
#
# 📦 Batch 13: Processing rows 1201 to 1300
#   ✅ dim_date: 21 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 0.2%
#
# 📦 Batch 14: Processing rows 1301 to 1400
#   ✅ dim_date: 21 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 436 records loaded
#   📈 Progress: 0.3%
#
# 📦 Batch 15: Processing rows 1401 to 1500
#   ✅ dim_date: 21 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 429 records loaded
#   📈 Progress: 0.3%
#
# 📦 Batch 16: Processing rows 1501 to 1600
#   ✅ dim_date: 20 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 41 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 25 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 410 records loaded
#   📈 Progress: 0.3%
#
# 📦 Batch 17: Processing rows 1601 to 1700
#   ✅ dim_date: 20 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 38 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 30 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 412 records loaded
#   📈 Progress: 0.3%
#
# 📦 Batch 18: Processing rows 1701 to 1800
#   ✅ dim_date: 19 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 423 records loaded
#   📈 Progress: 0.3%
#
# 📦 Batch 19: Processing rows 1801 to 1900
#   ✅ dim_date: 24 records
#   ✅ dim_product: 16 records
#   ✅ dim_company: 41 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 424 records loaded
#   📈 Progress: 0.3%
#
# 📦 Batch 20: Processing rows 1901 to 2000
#   ✅ dim_date: 27 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 0.4%
#
# 📦 Batch 21: Processing rows 2001 to 2100
#   ✅ dim_date: 26 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 435 records loaded
#   📈 Progress: 0.4%
#
# 📦 Batch 22: Processing rows 2101 to 2200
#   ✅ dim_date: 31 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 0.4%
#
# 📦 Batch 23: Processing rows 2201 to 2300
#   ✅ dim_date: 34 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 0.4%
#
# 📦 Batch 24: Processing rows 2301 to 2400
#   ✅ dim_date: 34 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 0.4%
#
# 📦 Batch 25: Processing rows 2401 to 2500
#   ✅ dim_date: 34 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 16 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 448 records loaded
#   📈 Progress: 0.4%
#
# 📦 Batch 26: Processing rows 2501 to 2600
#   ✅ dim_date: 36 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 0.5%
#
# 📦 Batch 27: Processing rows 2601 to 2700
#   ✅ dim_date: 38 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 0.5%
#
# 📦 Batch 28: Processing rows 2701 to 2800
#   ✅ dim_date: 31 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 0.5%
#
# 📦 Batch 29: Processing rows 2801 to 2900
#   ✅ dim_date: 28 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 0.5%
#
# 📦 Batch 30: Processing rows 2901 to 3000
#   ✅ dim_date: 28 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 435 records loaded
#   📈 Progress: 0.5%
#
# 📦 Batch 31: Processing rows 3001 to 3100
#   ✅ dim_date: 37 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 0.6%
#
# 📦 Batch 32: Processing rows 3101 to 3200
#   ✅ dim_date: 29 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 0.6%
#
# 📦 Batch 33: Processing rows 3201 to 3300
#   ✅ dim_date: 34 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 99 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 0.6%
#
# 📦 Batch 34: Processing rows 3301 to 3400
#   ✅ dim_date: 30 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 0.6%
#
# 📦 Batch 35: Processing rows 3401 to 3500
#   ✅ dim_date: 26 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 0.6%
#
# 📦 Batch 36: Processing rows 3501 to 3600
#   ✅ dim_date: 26 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 436 records loaded
#   📈 Progress: 0.6%
#
# 📦 Batch 37: Processing rows 3601 to 3700
#   ✅ dim_date: 26 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 0.7%
#
# 📦 Batch 38: Processing rows 3701 to 3800
#   ✅ dim_date: 29 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 42 records
#   ✅ dim_response: 16 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 0.7%
#
# 📦 Batch 39: Processing rows 3801 to 3900
#   ✅ dim_date: 31 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 42 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 0.7%
#
# 📦 Batch 40: Processing rows 3901 to 4000
#   ✅ dim_date: 30 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 446 records loaded
#   📈 Progress: 0.7%
#
# 📦 Batch 41: Processing rows 4001 to 4100
#   ✅ dim_date: 25 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 0.7%
#
# 📦 Batch 42: Processing rows 4101 to 4200
#   ✅ dim_date: 28 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 38 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 419 records loaded
#   📈 Progress: 0.8%
#
# 📦 Batch 43: Processing rows 4201 to 4300
#   ✅ dim_date: 26 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 429 records loaded
#   📈 Progress: 0.8%
#
# 📦 Batch 44: Processing rows 4301 to 4400
#   ✅ dim_date: 20 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 414 records loaded
#   📈 Progress: 0.8%
#
# 📦 Batch 45: Processing rows 4401 to 4500
#   ✅ dim_date: 24 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 425 records loaded
#   📈 Progress: 0.8%
#
# 📦 Batch 46: Processing rows 4501 to 4600
#   ✅ dim_date: 26 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 0.8%
#
# 📦 Batch 47: Processing rows 4601 to 4700
#   ✅ dim_date: 23 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 436 records loaded
#   📈 Progress: 0.8%
#
# 📦 Batch 48: Processing rows 4701 to 4800
#   ✅ dim_date: 25 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 30 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 427 records loaded
#   📈 Progress: 0.9%
#
# 📦 Batch 49: Processing rows 4801 to 4900
#   ✅ dim_date: 25 records
#   ✅ dim_product: 16 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 0.9%
#
# 📦 Batch 50: Processing rows 4901 to 5000
#   ✅ dim_date: 31 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 0.9%
#
# 📦 Batch 51: Processing rows 5001 to 5100
#   ✅ dim_date: 25 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 31 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 430 records loaded
#   📈 Progress: 0.9%
#
# 📦 Batch 52: Processing rows 5101 to 5200
#   ✅ dim_date: 25 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 31 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 426 records loaded
#   📈 Progress: 0.9%
#
# 📦 Batch 53: Processing rows 5201 to 5300
#   ✅ dim_date: 22 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 42 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 427 records loaded
#   📈 Progress: 1.0%
#
# 📦 Batch 54: Processing rows 5301 to 5400
#   ✅ dim_date: 25 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 16 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 431 records loaded
#   📈 Progress: 1.0%
#
# 📦 Batch 55: Processing rows 5401 to 5500
#   ✅ dim_date: 23 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 1.0%
#
# 📦 Batch 56: Processing rows 5501 to 5600
#   ✅ dim_date: 24 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 445 records loaded
#   📈 Progress: 1.0%
#
# 📦 Batch 57: Processing rows 5601 to 5700
#   ✅ dim_date: 23 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 41 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 420 records loaded
#   📈 Progress: 1.0%
#
# 📦 Batch 58: Processing rows 5701 to 5800
#   ✅ dim_date: 26 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 1.0%
#
# 📦 Batch 59: Processing rows 5801 to 5900
#   ✅ dim_date: 23 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 419 records loaded
#   📈 Progress: 1.1%
#
# 📦 Batch 60: Processing rows 5901 to 6000
#   ✅ dim_date: 26 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 1.1%
#
# 📦 Batch 61: Processing rows 6001 to 6100
#   ✅ dim_date: 30 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 1.1%
#
# 📦 Batch 62: Processing rows 6101 to 6200
#   ✅ dim_date: 24 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 86 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 1.1%
#
# 📦 Batch 63: Processing rows 6201 to 6300
#   ✅ dim_date: 26 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 1.1%
#
# 📦 Batch 64: Processing rows 6301 to 6400
#   ✅ dim_date: 20 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 432 records loaded
#   📈 Progress: 1.2%
#
# 📦 Batch 65: Processing rows 6401 to 6500
#   ✅ dim_date: 23 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 17 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 431 records loaded
#   📈 Progress: 1.2%
#
# 📦 Batch 66: Processing rows 6501 to 6600
#   ✅ dim_date: 19 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 42 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 421 records loaded
#   📈 Progress: 1.2%
#
# 📦 Batch 67: Processing rows 6601 to 6700
#   ✅ dim_date: 29 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 18 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 448 records loaded
#   📈 Progress: 1.2%
#
# 📦 Batch 68: Processing rows 6701 to 6800
#   ✅ dim_date: 27 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 1.2%
#
# 📦 Batch 69: Processing rows 6801 to 6900
#   ✅ dim_date: 24 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 430 records loaded
#   📈 Progress: 1.2%
#
# 📦 Batch 70: Processing rows 6901 to 7000
#   ✅ dim_date: 29 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 1.3%
#
# 📦 Batch 71: Processing rows 7001 to 7100
#   ✅ dim_date: 30 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 1.3%
#
# 📦 Batch 72: Processing rows 7101 to 7200
#   ✅ dim_date: 29 records
#   ✅ dim_product: 16 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 423 records loaded
#   📈 Progress: 1.3%
#
# 📦 Batch 73: Processing rows 7201 to 7300
#   ✅ dim_date: 27 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 1.3%
#
# 📦 Batch 74: Processing rows 7301 to 7400
#   ✅ dim_date: 27 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 1.3%
#
# 📦 Batch 75: Processing rows 7401 to 7500
#   ✅ dim_date: 29 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 444 records loaded
#   📈 Progress: 1.3%
#
# 📦 Batch 76: Processing rows 7501 to 7600
#   ✅ dim_date: 27 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 1.4%
#
# 📦 Batch 77: Processing rows 7601 to 7700
#   ✅ dim_date: 31 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 449 records loaded
#   📈 Progress: 1.4%
#
# 📦 Batch 78: Processing rows 7701 to 7800
#   ✅ dim_date: 26 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 1.4%
#
# 📦 Batch 79: Processing rows 7801 to 7900
#   ✅ dim_date: 23 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 431 records loaded
#   📈 Progress: 1.4%
#
# 📦 Batch 80: Processing rows 7901 to 8000
#   ✅ dim_date: 23 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 1.4%
#
# 📦 Batch 81: Processing rows 8001 to 8100
#   ✅ dim_date: 29 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 56 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 446 records loaded
#   📈 Progress: 1.5%
#
# 📦 Batch 82: Processing rows 8101 to 8200
#   ✅ dim_date: 22 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 1.5%
#
# 📦 Batch 83: Processing rows 8201 to 8300
#   ✅ dim_date: 29 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 1.5%
#
# 📦 Batch 84: Processing rows 8301 to 8400
#   ✅ dim_date: 33 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 457 records loaded
#   📈 Progress: 1.5%
#
# 📦 Batch 85: Processing rows 8401 to 8500
#   ✅ dim_date: 24 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 430 records loaded
#   📈 Progress: 1.5%
#
# 📦 Batch 86: Processing rows 8501 to 8600
#   ✅ dim_date: 29 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 449 records loaded
#   📈 Progress: 1.5%
#
# 📦 Batch 87: Processing rows 8601 to 8700
#   ✅ dim_date: 28 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 40 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 421 records loaded
#   📈 Progress: 1.6%
#
# 📦 Batch 88: Processing rows 8701 to 8800
#   ✅ dim_date: 29 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 1.6%
#
# 📦 Batch 89: Processing rows 8801 to 8900
#   ✅ dim_date: 25 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 449 records loaded
#   📈 Progress: 1.6%
#
# 📦 Batch 90: Processing rows 8901 to 9000
#   ✅ dim_date: 28 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 1.6%
#
# 📦 Batch 91: Processing rows 9001 to 9100
#   ✅ dim_date: 23 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 16 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 1.6%
#
# 📦 Batch 92: Processing rows 9101 to 9200
#   ✅ dim_date: 24 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 99 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 16 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 444 records loaded
#   📈 Progress: 1.7%
#
# 📦 Batch 93: Processing rows 9201 to 9300
#   ✅ dim_date: 20 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 42 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 442 records loaded
#   📈 Progress: 1.7%
#
# 📦 Batch 94: Processing rows 9301 to 9400
#   ✅ dim_date: 32 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 436 records loaded
#   📈 Progress: 1.7%
#
# 📦 Batch 95: Processing rows 9401 to 9500
#   ✅ dim_date: 24 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 1.7%
#
# 📦 Batch 96: Processing rows 9501 to 9600
#   ✅ dim_date: 30 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 42 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 1.7%
#
# 📦 Batch 97: Processing rows 9601 to 9700
#   ✅ dim_date: 21 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 424 records loaded
#   📈 Progress: 1.7%
#
# 📦 Batch 98: Processing rows 9701 to 9800
#   ✅ dim_date: 28 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 1.8%
#
# 📦 Batch 99: Processing rows 9801 to 9900
#   ✅ dim_date: 22 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 43 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 436 records loaded
#   📈 Progress: 1.8%
#
# 📦 Batch 100: Processing rows 9901 to 10000
#   ✅ dim_date: 22 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 430 records loaded
#   📈 Progress: 1.8%
#
# 📦 Batch 101: Processing rows 10001 to 10100
#   ✅ dim_date: 22 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 1.8%
#
# 📦 Batch 102: Processing rows 10101 to 10200
#   ✅ dim_date: 24 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 44 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 1.8%
#
# 📦 Batch 103: Processing rows 10201 to 10300
#   ✅ dim_date: 23 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 1.9%
#
# 📦 Batch 104: Processing rows 10301 to 10400
#   ✅ dim_date: 23 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 420 records loaded
#   📈 Progress: 1.9%
#
# 📦 Batch 105: Processing rows 10401 to 10500
#   ✅ dim_date: 23 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 56 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 8 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 1.9%
#
# 📦 Batch 106: Processing rows 10501 to 10600
#   ✅ dim_date: 21 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 444 records loaded
#   📈 Progress: 1.9%
#
# 📦 Batch 107: Processing rows 10601 to 10700
#   ✅ dim_date: 23 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 45 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 454 records loaded
#   📈 Progress: 1.9%
#
# 📦 Batch 108: Processing rows 10701 to 10800
#   ✅ dim_date: 23 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 427 records loaded
#   📈 Progress: 1.9%
#
# 📦 Batch 109: Processing rows 10801 to 10900
#   ✅ dim_date: 19 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 2.0%
#
# 📦 Batch 110: Processing rows 10901 to 11000
#   ✅ dim_date: 25 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 431 records loaded
#   📈 Progress: 2.0%
#
# 📦 Batch 111: Processing rows 11001 to 11100
#   ✅ dim_date: 24 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 435 records loaded
#   📈 Progress: 2.0%
#
# 📦 Batch 112: Processing rows 11101 to 11200
#   ✅ dim_date: 30 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 80 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 429 records loaded
#   📈 Progress: 2.0%
#
# 📦 Batch 113: Processing rows 11201 to 11300
#   ✅ dim_date: 28 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 43 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 447 records loaded
#   📈 Progress: 2.0%
#
# 📦 Batch 114: Processing rows 11301 to 11400
#   ✅ dim_date: 31 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 445 records loaded
#   📈 Progress: 2.1%
#
# 📦 Batch 115: Processing rows 11401 to 11500
#   ✅ dim_date: 33 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 83 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 2.1%
#
# 📦 Batch 116: Processing rows 11501 to 11600
#   ✅ dim_date: 30 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 2.1%
#
# 📦 Batch 117: Processing rows 11601 to 11700
#   ✅ dim_date: 33 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 2.1%
#
# 📦 Batch 118: Processing rows 11701 to 11800
#   ✅ dim_date: 36 records
#   ✅ dim_product: 16 records
#   ✅ dim_company: 47 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 2.1%
#
# 📦 Batch 119: Processing rows 11801 to 11900
#   ✅ dim_date: 35 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 56 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 456 records loaded
#   📈 Progress: 2.1%
#
# 📦 Batch 120: Processing rows 11901 to 12000
#   ✅ dim_date: 31 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 443 records loaded
#   📈 Progress: 2.2%
#
# 📦 Batch 121: Processing rows 12001 to 12100
#   ✅ dim_date: 34 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 56 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 452 records loaded
#   📈 Progress: 2.2%
#
# 📦 Batch 122: Processing rows 12101 to 12200
#   ✅ dim_date: 29 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 449 records loaded
#   📈 Progress: 2.2%
#
# 📦 Batch 123: Processing rows 12201 to 12300
#   ✅ dim_date: 31 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 436 records loaded
#   📈 Progress: 2.2%
#
# 📦 Batch 124: Processing rows 12301 to 12400
#   ✅ dim_date: 30 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 58 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 452 records loaded
#   📈 Progress: 2.2%
#
# 📦 Batch 125: Processing rows 12401 to 12500
#   ✅ dim_date: 29 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 42 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 2.2%
#
# 📦 Batch 126: Processing rows 12501 to 12600
#   ✅ dim_date: 31 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 41 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 2.3%
#
# 📦 Batch 127: Processing rows 12601 to 12700
#   ✅ dim_date: 32 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 452 records loaded
#   📈 Progress: 2.3%
#
# 📦 Batch 128: Processing rows 12701 to 12800
#   ✅ dim_date: 36 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 2.3%
#
# 📦 Batch 129: Processing rows 12801 to 12900
#   ✅ dim_date: 32 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 85 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 2.3%
#
# 📦 Batch 130: Processing rows 12901 to 13000
#   ✅ dim_date: 36 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 86 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 2.3%
#
# 📦 Batch 131: Processing rows 13001 to 13100
#   ✅ dim_date: 32 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 68 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 477 records loaded
#   📈 Progress: 2.4%
#
# 📦 Batch 132: Processing rows 13101 to 13200
#   ✅ dim_date: 33 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 86 records
#   ✅ dim_issue: 30 records
#   ✅ dim_response: 16 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 430 records loaded
#   📈 Progress: 2.4%
#
# 📦 Batch 133: Processing rows 13201 to 13300
#   ✅ dim_date: 34 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 98 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 2.4%
#
# 📦 Batch 134: Processing rows 13301 to 13400
#   ✅ dim_date: 28 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 2.4%
#
# 📦 Batch 135: Processing rows 13401 to 13500
#   ✅ dim_date: 34 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 2.4%
#
# 📦 Batch 136: Processing rows 13501 to 13600
#   ✅ dim_date: 32 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 57 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 43 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 2.4%
#
# 📦 Batch 137: Processing rows 13601 to 13700
#   ✅ dim_date: 36 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 42 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 53 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 459 records loaded
#   📈 Progress: 2.5%
#
# 📦 Batch 138: Processing rows 13701 to 13800
#   ✅ dim_date: 32 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 59 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 42 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 460 records loaded
#   📈 Progress: 2.5%
#
# 📦 Batch 139: Processing rows 13801 to 13900
#   ✅ dim_date: 33 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 46 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 47 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 2.5%
#
# 📦 Batch 140: Processing rows 13901 to 14000
#   ✅ dim_date: 31 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 40 records
#   ✅ dim_location: 99 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 2.5%
#
# 📦 Batch 141: Processing rows 14001 to 14100
#   ✅ dim_date: 35 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 2.5%
#
# 📦 Batch 142: Processing rows 14101 to 14200
#   ✅ dim_date: 32 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 443 records loaded
#   📈 Progress: 2.6%
#
# 📦 Batch 143: Processing rows 14201 to 14300
#   ✅ dim_date: 31 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 452 records loaded
#   📈 Progress: 2.6%
#
# 📦 Batch 144: Processing rows 14301 to 14400
#   ✅ dim_date: 33 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 62 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 12 records
# ...
#   ✅ dim_date: 28 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 38.9%
#
# 📦 Batch 2162: Processing rows 216101 to 216200
#   ✅ dim_date: 26 records
#   ✅ dim_product: 27 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 46 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 458 records loaded
#   📈 Progress: 38.9%
#
# 📦 Batch 2163: Processing rows 216201 to 216300
#   ✅ dim_date: 23 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 438 records loaded
#   📈 Progress: 38.9%
#
# 📦 Batch 2164: Processing rows 216301 to 216400
#   ✅ dim_date: 21 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 49 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 38.9%
#
# 📦 Batch 2165: Processing rows 216401 to 216500
#   ✅ dim_date: 26 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 48 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 38.9%
#
# 📦 Batch 2166: Processing rows 216501 to 216600
#   ✅ dim_date: 22 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 85 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 428 records loaded
#   📈 Progress: 39.0%
#
# 📦 Batch 2167: Processing rows 216601 to 216700
#   ✅ dim_date: 22 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 39.0%
#
# 📦 Batch 2168: Processing rows 216701 to 216800
#   ✅ dim_date: 24 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 446 records loaded
#   📈 Progress: 39.0%
#
# 📦 Batch 2169: Processing rows 216801 to 216900
#   ✅ dim_date: 23 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 60 records
#   ✅ dim_location: 83 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 39.0%
#
# 📦 Batch 2170: Processing rows 216901 to 217000
#   ✅ dim_date: 22 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 39.0%
#
# 📦 Batch 2171: Processing rows 217001 to 217100
#   ✅ dim_date: 21 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 58 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 38 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 39.0%
#
# 📦 Batch 2172: Processing rows 217101 to 217200
#   ✅ dim_date: 27 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 58 records
#   ✅ dim_location: 92 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 450 records loaded
#   📈 Progress: 39.1%
#
# 📦 Batch 2173: Processing rows 217201 to 217300
#   ✅ dim_date: 23 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 82 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 425 records loaded
#   📈 Progress: 39.1%
#
# 📦 Batch 2174: Processing rows 217301 to 217400
#   ✅ dim_date: 22 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 427 records loaded
#   📈 Progress: 39.1%
#
# 📦 Batch 2175: Processing rows 217401 to 217500
#   ✅ dim_date: 28 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 90 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 39.1%
#
# 📦 Batch 2176: Processing rows 217501 to 217600
#   ✅ dim_date: 21 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 64 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 32 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 444 records loaded
#   📈 Progress: 39.1%
#
# 📦 Batch 2177: Processing rows 217601 to 217700
#   ✅ dim_date: 29 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 60 records
#   ✅ dim_location: 85 records
#   ✅ dim_issue: 33 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 39.2%
#
# 📦 Batch 2178: Processing rows 217701 to 217800
#   ✅ dim_date: 29 records
#   ✅ dim_product: 26 records
#   ✅ dim_company: 59 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 458 records loaded
#   📈 Progress: 39.2%
#
# 📦 Batch 2179: Processing rows 217801 to 217900
#   ✅ dim_date: 32 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 39.2%
#
# 📦 Batch 2180: Processing rows 217901 to 218000
#   ✅ dim_date: 34 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 60 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 39.2%
#
# 📦 Batch 2181: Processing rows 218001 to 218100
#   ✅ dim_date: 23 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 432 records loaded
#   📈 Progress: 39.2%
#
# 📦 Batch 2182: Processing rows 218101 to 218200
#   ✅ dim_date: 28 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 447 records loaded
#   📈 Progress: 39.2%
#
# 📦 Batch 2183: Processing rows 218201 to 218300
#   ✅ dim_date: 27 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 97 records
#   ✅ dim_issue: 46 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 453 records loaded
#   📈 Progress: 39.3%
#
# 📦 Batch 2184: Processing rows 218301 to 218400
#   ✅ dim_date: 26 records
#   ✅ dim_product: 16 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 39.3%
#
# 📦 Batch 2185: Processing rows 218401 to 218500
#   ✅ dim_date: 26 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 43 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 34 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 423 records loaded
#   📈 Progress: 39.3%
#
# 📦 Batch 2186: Processing rows 218501 to 218600
#   ✅ dim_date: 25 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 94 records
#   ✅ dim_issue: 35 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 439 records loaded
#   📈 Progress: 39.3%
#
# 📦 Batch 2187: Processing rows 218601 to 218700
#   ✅ dim_date: 22 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 61 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 448 records loaded
#   📈 Progress: 39.3%
#
# 📦 Batch 2188: Processing rows 218701 to 218800
#   ✅ dim_date: 29 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 95 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 448 records loaded
#   📈 Progress: 39.4%
#
# 📦 Batch 2189: Processing rows 218801 to 218900
#   ✅ dim_date: 27 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 60 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 39.4%
#
# 📦 Batch 2190: Processing rows 218901 to 219000
#   ✅ dim_date: 30 records
#   ✅ dim_product: 17 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 85 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 429 records loaded
#   📈 Progress: 39.4%
#
# 📦 Batch 2191: Processing rows 219001 to 219100
#   ✅ dim_date: 30 records
#   ✅ dim_product: 19 records
#   ✅ dim_company: 59 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 446 records loaded
#   📈 Progress: 39.4%
#
# 📦 Batch 2192: Processing rows 219101 to 219200
#   ✅ dim_date: 23 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 42 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 435 records loaded
#   📈 Progress: 39.4%
#
# 📦 Batch 2193: Processing rows 219201 to 219300
#   ✅ dim_date: 25 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 53 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 13 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 39.4%
#
# 📦 Batch 2194: Processing rows 219301 to 219400
#   ✅ dim_date: 23 records
#   ✅ dim_product: 23 records
#   ✅ dim_company: 52 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 37 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 435 records loaded
#   📈 Progress: 39.5%
#
# 📦 Batch 2195: Processing rows 219401 to 219500
#   ✅ dim_date: 27 records
#   ✅ dim_product: 18 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 441 records loaded
#   📈 Progress: 39.5%
#
# 📦 Batch 2196: Processing rows 219501 to 219600
#   ✅ dim_date: 23 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 51 records
#   ✅ dim_location: 88 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 14 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 39.5%
#
# 📦 Batch 2197: Processing rows 219601 to 219700
#   ✅ dim_date: 24 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 61 records
#   ✅ dim_location: 96 records
#   ✅ dim_issue: 43 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 458 records loaded
#   📈 Progress: 39.5%
#
# 📦 Batch 2198: Processing rows 219701 to 219800
#   ✅ dim_date: 19 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 55 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 46 records
#   ✅ dim_response: 11 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 449 records loaded
#   📈 Progress: 39.5%
#
# 📦 Batch 2199: Processing rows 219801 to 219900
#   ✅ dim_date: 24 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 45 records
#   ✅ dim_location: 89 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 15 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 434 records loaded
#   📈 Progress: 39.6%
#
# 📦 Batch 2200: Processing rows 219901 to 220000
#   ✅ dim_date: 26 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 49 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 44 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 447 records loaded
#   📈 Progress: 39.6%
#
# 📦 Batch 2201: Processing rows 220001 to 220100
#   ✅ dim_date: 21 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 91 records
#   ✅ dim_issue: 46 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 447 records loaded
#   📈 Progress: 39.6%
#
# 📦 Batch 2202: Processing rows 220101 to 220200
#   ✅ dim_date: 20 records
#   ✅ dim_product: 25 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 93 records
#   ✅ dim_issue: 40 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 440 records loaded
#   📈 Progress: 39.6%
#
# 📦 Batch 2203: Processing rows 220201 to 220300
#   ✅ dim_date: 23 records
#   ✅ dim_product: 20 records
#   ✅ dim_company: 57 records
#   ✅ dim_location: 87 records
#   ✅ dim_issue: 41 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 437 records loaded
#   📈 Progress: 39.6%
#
# 📦 Batch 2204: Processing rows 220301 to 220400
#   ✅ dim_date: 25 records
#   ✅ dim_product: 22 records
#   ✅ dim_company: 61 records
#   ✅ dim_location: 85 records
#   ✅ dim_issue: 46 records
#   ✅ dim_response: 12 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 451 records loaded
#   📈 Progress: 39.6%
#
# 📦 Batch 2205: Processing rows 220401 to 220500
#   ✅ dim_date: 19 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 50 records
#   ✅ dim_location: 86 records
#   ✅ dim_issue: 39 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 424 records loaded
#   📈 Progress: 39.7%
#
# 📦 Batch 2206: Processing rows 220501 to 220600
#   ✅ dim_date: 10 records
#   ✅ dim_product: 24 records
#   ✅ dim_company: 56 records
#   ✅ dim_location: 83 records
#   ✅ dim_issue: 49 records
#   ✅ dim_response: 10 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 432 records loaded
#   📈 Progress: 39.7%
#
# 📦 Batch 2207: Processing rows 220601 to 220700
#   ✅ dim_date: 18 records
#   ✅ dim_product: 21 records
#   ✅ dim_company: 54 records
#   ✅ dim_location: 85 records
#   ✅ dim_issue: 36 records
#   ✅ dim_response: 9 records
#   ✅ dim_complaint_detail: 100 records
#   ✅ fact_complaints: 100 records
#   📊 Batch total: 423 records loaded
#   📈 Progress: 39.7%
#
# 📦 Batch 2208: Processing rows 220701 to 220800

# %%
print("\n🔍 VERIFY: Checking data warehouse...")

# Check record counts
tables = ['dim_date', 'dim_product', 'dim_company', 'dim_location', 
          'dim_issue', 'dim_response', 'dim_complaint_detail', 'fact_complaints']

print("📊 Final record counts:")
total_records = 0

for table in tables:
    try:
        count = supabase.table(table).select("*", count="exact").execute().count
        print(f"  📋 {table:<25}: {count:>6,} records")
        total_records += count
    except Exception as e:
        print(f"  ❌ {table:<25}: Error - {e}")

print(f"\n🎯 Total records in DW: {total_records:,}")
print(f"📊 From {len(cleaned_data):,} input rows")
print(f"💡 Ratio: {total_records/len(cleaned_data):.1f}x (1 input row → multiple DW records)")

# Sample verification - check if data is properly distributed
print("\n🔍 Sample verification:")
try:
    # Get sample fact record
    fact_sample = supabase.table('fact_complaints').select('*').limit(1).execute()
    if fact_sample.data:
        fact_record = fact_sample.data[0]
        print(f"✅ Sample fact record ID: {fact_record['complaint_detail_key']}")
        
        # Check if related dimension records exist
        checks = [
            ('dim_complaint_detail', 'complaint_detail_key', fact_record['complaint_detail_key']),
            ('dim_date', 'date_key', fact_record['date_received_key']),
            ('dim_product', 'product_key', fact_record['product_key']),
            ('dim_company', 'company_key', fact_record['company_key'])
        ]
        
        for table, key_field, key_value in checks:
            check = supabase.table(table).select('*').eq(key_field, key_value).execute()
            if check.data:
                print(f"✅ Related {table} record exists")
            else:
                print(f"❌ Missing {table} record for key {key_value}")
    
except Exception as e:
    print(f"⚠️ Verification error: {e}")

print("\n🎉 ETL COMPLETED SUCCESSFULLY!")
print("💡 Your star schema data warehouse is ready for analysis!")
print("🚀 Next: Connect your BI tool to Supabase and start analyzing!")
# Out:
# 🔍 VERIFY: Checking data warehouse...
# 📊 Final record counts:
#   📋 dim_date                 :     49 records
#   📋 dim_product              :     28 records
#   📋 dim_company              :    202 records
#   📋 dim_location             :    853 records
#   📋 dim_issue                :     85 records
#   📋 dim_response             :     21 records
#   📋 dim_complaint_detail     :  1,000 records
#   📋 fact_complaints          :  1,000 records
#
# 🎯 Total records in DW: 3,238
# 📊 From 1,000 input rows
# 💡 Ratio: 3.2x (1 input row → multiple DW records)
#
# 🔍 Sample verification:
# ✅ Sample fact record ID: 511074
# ✅ Related dim_complaint_detail record exists
# ✅ Related dim_date record exists
# ✅ Related dim_product record exists
# ✅ Related dim_company record exists
#
# 🎉 ETL COMPLETED SUCCESSFULLY!
# 💡 Your star schema data warehouse is ready for analysis!
# 🚀 Next: Connect your BI tool to Supabase and start analyzing!
